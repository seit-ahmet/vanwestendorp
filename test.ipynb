# %%
import pandas as pd
import VanWestendorp_PriceSensitivityMeter as VWPSM

# %%
my_data = pd.read_csv("my_data.csv")
my_data.head()
# Out:
#    Too Cheap  Cheap  Expensive  Too Expensive
# 0         10     20         30             40
# 1         15     25         40             55
# 2         25     30         35             40
# 3          5     15         25             35

# %%
my_cols = ['Too Cheap', 'Cheap', 'Expensive', 'Too Expensive']

# %%
VWPSM.results(my_data, my_cols)
# Out:
# Total data set contains 4 cases, 4 cases were kept (transitive price preferences).
#
# Accepted Price Range: $15.00 - $35.00
# Indifference Price Point: $25.00
# Optimal Price Point: $25.00
